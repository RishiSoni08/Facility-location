# %%
import pandas as pd 
import numpy as np 
import pulp 
import folium

# %%
data = pd.read_csv('distance_matrix.csv', index_col=0)

data

map = folium.Map(location=(23.25,77.41),zoom_start =5,max_zoom=10,min_zoom=5)
map

for i in range (50):
    cord = (data.iloc[i][50],data.iloc[i][51])
    folium.Marker(location=cord,
                  icon= folium.Icon(icon='glyphicon-map-marker',
                                     prefix='glyphicon', 
                                     icon_size=(5,5), 
                                     icon_color='red',shadow_size=(0,0)),
                    popup=data.index[i]).add_to(map)

map
# Out:
# /tmp/ipykernel_44729/2051879957.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cord = (data.iloc[i][50],data.iloc[i][51])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67e11a02490fde7368c363f44d87b75c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67e11a02490fde7368c363f44d87b75c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67e11a02490fde7368c363f44d87b75c = L.map(
#                 &quot;map_67e11a02490fde7368c363f44d87b75c&quot;,
#                 {
#                     center: [23.25, 77.41],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b5bdd09ae941b5353c5ca4ee8157fc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 10, &quot;minZoom&quot;: 5, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5b5bdd09ae941b5353c5ca4ee8157fc3.addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var marker_36de4c2f4f1b692cba8df29ceb17e368 = L.marker(
#                 [19.076, 72.8777],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_c6dbfc01ec7f1de066f5b174e983caa1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_36de4c2f4f1b692cba8df29ceb17e368.setIcon(icon_c6dbfc01ec7f1de066f5b174e983caa1);
#
#
#         var popup_a598c5b7fd44f92e66d4127c9d79b20e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4be14dd2b5ddd113c4d74a0dd1a0e934 = $(`&lt;div id=&quot;html_4be14dd2b5ddd113c4d74a0dd1a0e934&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mumbai&lt;/div&gt;`)[0];
#                 popup_a598c5b7fd44f92e66d4127c9d79b20e.setContent(html_4be14dd2b5ddd113c4d74a0dd1a0e934);
#
#
#
#         marker_36de4c2f4f1b692cba8df29ceb17e368.bindPopup(popup_a598c5b7fd44f92e66d4127c9d79b20e)
#         ;
#
#
#
#
#             var marker_0b1b98a2f3ac84f53095ac4ff32171d8 = L.marker(
#                 [28.7041, 77.1025],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_5ed0d28f676df8877afe7afedefe58c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_0b1b98a2f3ac84f53095ac4ff32171d8.setIcon(icon_5ed0d28f676df8877afe7afedefe58c2);
#
#
#         var popup_5a1b8b0cd3c529acd95d934f1b623ccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d741fd980265277b2866df0c9683a9c8 = $(`&lt;div id=&quot;html_d741fd980265277b2866df0c9683a9c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi&lt;/div&gt;`)[0];
#                 popup_5a1b8b0cd3c529acd95d934f1b623ccf.setContent(html_d741fd980265277b2866df0c9683a9c8);
#
#
#
#         marker_0b1b98a2f3ac84f53095ac4ff32171d8.bindPopup(popup_5a1b8b0cd3c529acd95d934f1b623ccf)
#         ;
#
#
#
#
#             var marker_5bb66db07117e13c90f60fa5573c557c = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_d9916681b291b9f1ed98097749bac0c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_5bb66db07117e13c90f60fa5573c557c.setIcon(icon_d9916681b291b9f1ed98097749bac0c2);
#
#
#         var popup_f8b7af2dbe14ab74bbb463d887afb224 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_284188c8bb4d20fdf4db9cf1a01eb76d = $(`&lt;div id=&quot;html_284188c8bb4d20fdf4db9cf1a01eb76d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bengaluru&lt;/div&gt;`)[0];
#                 popup_f8b7af2dbe14ab74bbb463d887afb224.setContent(html_284188c8bb4d20fdf4db9cf1a01eb76d);
#
#
#
#         marker_5bb66db07117e13c90f60fa5573c557c.bindPopup(popup_f8b7af2dbe14ab74bbb463d887afb224)
#         ;
#
#
#
#
#             var marker_d008641b530476651dbca9c836454120 = L.marker(
#                 [17.385, 78.4867],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_6d5a2d53acffa783c62aa176dea3bb80 = L.AwesomeMa

# %%
# Define the problem
prob = pulp.LpProblem("Facility Location", pulp.LpMinimize)

# Parameters
num_faci = 50
num_dema = 50
# Out:
# /home/delhivery/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1316: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
x = pulp.LpVariable.dicts('X', range(num_faci), cat='Binary')
y = pulp.LpVariable.dicts('Y', (range(num_dema), range(num_faci)), cat='Binary')

# %%
# Objective function
prob += pulp.lpSum(y[demand][facility] * data.iloc[facility, demand]
                   for demand in range(num_dema)
                   for facility in range(num_faci))

# %%
#Total number of facilities constraint = 3
prob += pulp.lpSum(x[facility] for facility in range(num_faci)) == 3, 'Total_Facilities'

# Every demand zone is connected to one facility only
for demand in range(num_dema):
    prob += pulp.lpSum(y[demand][facility] for facility in range(num_faci)) == 1, f'demand_{demand}'

# Contingency Condition: yij <= xi
for demand in range(num_dema):
    for facility in range(num_faci):
        prob += y[demand][facility] <= x[facility], f'Contingency_{demand}_{facility}'

# %%
# Solve the problem
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/delhivery/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f3a72d9a0198414dbebdcd8aa550c3b0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/f3a72d9a0198414dbebdcd8aa550c3b0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2556 COLUMNS
# At line 17657 RHS
# At line 20209 BOUNDS
# At line 22760 ENDATA
# Problem MODEL has 2551 rows, 2550 columns and 7550 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 18928.4 - 0.08 seconds
# Cgl0004I processed model has 2551 rows, 2550 columns (2550 integer (2550 of which binary)) and 7550 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 18928.4
# Cbc0038I Before mini branch and bound, 2550 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I After 0.12 seconds - Feasibility pump exiting with objective of 18928.4 - took 0.01 seconds
# Cbc0012I Integer solution of 18928.424 found by feasibility pump after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0001I Search completed - best objective 18928.42373364071, took 0 iterations and 0 nodes (0.12 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 18928.4 to 18928.4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                18928.42373364
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.12
# Time (Wallclock seconds):       0.13
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.13   (Wallclock seconds):       0.14
# 1

# %%
# Print the status
print("Status:", pulp.LpStatus[prob.status])

# Print the results
for facility in range(num_faci):
    if pulp.value(x[facility])== 1:
        print(f'Facility {data.index[facility]} is open')
        #print(f'X[{facility}] =', pulp.value(x[facility]))
    
for demand in range(num_dema):
    for facility in range(num_faci):
        if pulp.value(y[demand][facility])==1:
            print(f'{data.index[facility]} is supplying to {data.index[demand]}')
            #print(f'Y[{demand}][{facility}] =', pulp.value(y[demand][facility]))
# Out:
# Status: Optimal
# Facility Faridabad is open
# Facility Ranchi is open
# Facility Solapur is open
# Solapur is supplying to Mumbai
# Faridabad is supplying to Delhi
# Solapur is supplying to Bengaluru
# Solapur is supplying to Hyderabad
# Solapur is supplying to Ahmedabad
# Solapur is supplying to Chennai
# Ranchi is supplying to Kolkata
# Solapur is supplying to Pune
# Faridabad is supplying to Jaipur
# Solapur is supplying to Surat
# Faridabad is supplying to Lucknow
# Faridabad is supplying to Kanpur
# Solapur is supplying to Nagpur
# Ranchi is supplying to Visakhapatnam
# Faridabad is supplying to Bhopal
# Ranchi is supplying to Patna
# Faridabad is supplying to Ludhiana
# Faridabad is supplying to Agra
# Solapur is supplying to Nashik
# Faridabad is supplying to Faridabad
# Faridabad is supplying to Meerut
# Solapur is supplying to Rajkot
# Ranchi is supplying to Varanasi
# Faridabad is supplying to Srinagar
# Solapur is supplying to Aurangabad
# Ranchi is supplying to Dhanbad
# Faridabad is supplying to Amritsar
# Solapur is supplying to Navi Mumbai
# Ranchi is supplying to Allahabad
# Ranchi is supplying to Ranchi
# Ranchi is supplying to Howrah
# Solapur is supplying to Coimbatore
# Ranchi is supplying to Jabalpur
# Faridabad is supplying to Gwalior
# Solapur is supplying to Vijayawada
# Faridabad is supplying to Jodhpur
# Solapur is supplying to Madurai
# Ranchi is supplying to Raipur
# Faridabad is supplying to Kota
# Ranchi is supplying to Guwahati
# Faridabad is supplying to Chandigarh
# Solapur is supplying to Solapur
# Solapur is supplying to Hubli
# Solapur is supplying to Mysore
# Solapur is supplying to Tiruchirappalli
# Faridabad is supplying to Bareilly
# Faridabad is supplying to Aligarh
# Faridabad is supplying to Moradabad
# Faridabad is supplying to Gurgaon
# Faridabad is supplying to Jalandhar

# %%
# Plot the route
for demand in range(num_dema):
    for facility in range(num_faci):
        if pulp.value(y[demand][facility])==1:
            waypoints = [(data.iloc[facility][50],data.iloc[facility][51]),
                         (data.iloc[demand][50],data.iloc[demand][51])]
            #print(f'{data.index[facility]} is supplying to {data.index[demand]}')
            folium.PolyLine(locations=waypoints, color='blue', weight=2, opacity=1).add_to(map)
# Out:
# /tmp/ipykernel_44729/1238802938.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   waypoints = [(data.iloc[facility][50],data.iloc[facility][51]),
# /tmp/ipykernel_44729/1238802938.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   (data.iloc[demand][50],data.iloc[demand][51])]

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67e11a02490fde7368c363f44d87b75c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67e11a02490fde7368c363f44d87b75c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67e11a02490fde7368c363f44d87b75c = L.map(
#                 &quot;map_67e11a02490fde7368c363f44d87b75c&quot;,
#                 {
#                     center: [23.25, 77.41],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b5bdd09ae941b5353c5ca4ee8157fc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 10, &quot;minZoom&quot;: 5, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5b5bdd09ae941b5353c5ca4ee8157fc3.addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var marker_36de4c2f4f1b692cba8df29ceb17e368 = L.marker(
#                 [19.076, 72.8777],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_c6dbfc01ec7f1de066f5b174e983caa1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_36de4c2f4f1b692cba8df29ceb17e368.setIcon(icon_c6dbfc01ec7f1de066f5b174e983caa1);
#
#
#         var popup_a598c5b7fd44f92e66d4127c9d79b20e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4be14dd2b5ddd113c4d74a0dd1a0e934 = $(`&lt;div id=&quot;html_4be14dd2b5ddd113c4d74a0dd1a0e934&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mumbai&lt;/div&gt;`)[0];
#                 popup_a598c5b7fd44f92e66d4127c9d79b20e.setContent(html_4be14dd2b5ddd113c4d74a0dd1a0e934);
#
#
#
#         marker_36de4c2f4f1b692cba8df29ceb17e368.bindPopup(popup_a598c5b7fd44f92e66d4127c9d79b20e)
#         ;
#
#
#
#
#             var marker_0b1b98a2f3ac84f53095ac4ff32171d8 = L.marker(
#                 [28.7041, 77.1025],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_5ed0d28f676df8877afe7afedefe58c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_0b1b98a2f3ac84f53095ac4ff32171d8.setIcon(icon_5ed0d28f676df8877afe7afedefe58c2);
#
#
#         var popup_5a1b8b0cd3c529acd95d934f1b623ccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d741fd980265277b2866df0c9683a9c8 = $(`&lt;div id=&quot;html_d741fd980265277b2866df0c9683a9c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi&lt;/div&gt;`)[0];
#                 popup_5a1b8b0cd3c529acd95d934f1b623ccf.setContent(html_d741fd980265277b2866df0c9683a9c8);
#
#
#
#         marker_0b1b98a2f3ac84f53095ac4ff32171d8.bindPopup(popup_5a1b8b0cd3c529acd95d934f1b623ccf)
#         ;
#
#
#
#
#             var marker_5bb66db07117e13c90f60fa5573c557c = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_d9916681b291b9f1ed98097749bac0c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_5bb66db07117e13c90f60fa5573c557c.setIcon(icon_d9916681b291b9f1ed98097749bac0c2);
#
#
#         var popup_f8b7af2dbe14ab74bbb463d887afb224 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_284188c8bb4d20fdf4db9cf1a01eb76d = $(`&lt;div id=&quot;html_284188c8bb4d20fdf4db9cf1a01eb76d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bengaluru&lt;/div&gt;`)[0];
#                 popup_f8b7af2dbe14ab74bbb463d887afb224.setContent(html_284188c8bb4d20fdf4db9cf1a01eb76d);
#
#
#
#         marker_5bb66db07117e13c90f60fa5573c557c.bindPopup(popup_f8b7af2dbe14ab74bbb463d887afb224)
#         ;
#
#
#
#
#             var marker_d008641b530476651dbca9c836454120 = L.marker(
#                 [17.385, 78.4867],
#                 {}
#             ).addTo(map_67e11a02490fde7368c363f44d87b75c);
#
#
#             var icon_6d5a2d53acffa783c62aa176dea3bb80 = L.AwesomeMa
