# %%
import pandas as pd 
import numpy as np 
import pulp 
import folium

# %%
data = pd.read_csv('distance_matrix.csv', index_col=0)

data

map = folium.Map(location=(23.25,77.41),zoom_start =5,max_zoom=10,min_zoom=5)
map

for i in range (50):
    cord = (data.iloc[i][50],data.iloc[i][51])
    folium.Marker(location=cord,
                  icon= folium.Icon(icon='glyphicon-map-marker',
                                     prefix='glyphicon', 
                                     icon_size=(5,5), 
                                     icon_color='red',shadow_size=(0,0)),
                    popup=data.index[i]).add_to(map)

map
# Out:
# /tmp/ipykernel_44729/2051879957.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cord = (data.iloc[i][50],data.iloc[i][51])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b999ffce51a2739a00877fe1f1803f70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b999ffce51a2739a00877fe1f1803f70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b999ffce51a2739a00877fe1f1803f70 = L.map(
#                 &quot;map_b999ffce51a2739a00877fe1f1803f70&quot;,
#                 {
#                     center: [23.25, 77.41],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e476bd3161744970a87f2dc4577bb5a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 10, &quot;minZoom&quot;: 5, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e476bd3161744970a87f2dc4577bb5a4.addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var marker_3cb9294b1fe728ec82de7e255160a640 = L.marker(
#                 [19.076, 72.8777],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_ac82a2e30d32961a913d0e94fd5acdae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_3cb9294b1fe728ec82de7e255160a640.setIcon(icon_ac82a2e30d32961a913d0e94fd5acdae);
#
#
#         var popup_cc08bad7574c10e7d7b21051014d2983 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d6e678e1cdcfddb73cd573a50604b9e = $(`&lt;div id=&quot;html_4d6e678e1cdcfddb73cd573a50604b9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mumbai&lt;/div&gt;`)[0];
#                 popup_cc08bad7574c10e7d7b21051014d2983.setContent(html_4d6e678e1cdcfddb73cd573a50604b9e);
#
#
#
#         marker_3cb9294b1fe728ec82de7e255160a640.bindPopup(popup_cc08bad7574c10e7d7b21051014d2983)
#         ;
#
#
#
#
#             var marker_aaf2002705dd59e148c70d046f2d7c2d = L.marker(
#                 [28.7041, 77.1025],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_a439165bb65cddcea7f6e7c12477e7c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_aaf2002705dd59e148c70d046f2d7c2d.setIcon(icon_a439165bb65cddcea7f6e7c12477e7c7);
#
#
#         var popup_dc4438f824d40bc1a7947b158e2e2927 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ac81d5b2e67fd92358b7c4ef8f723c3 = $(`&lt;div id=&quot;html_2ac81d5b2e67fd92358b7c4ef8f723c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi&lt;/div&gt;`)[0];
#                 popup_dc4438f824d40bc1a7947b158e2e2927.setContent(html_2ac81d5b2e67fd92358b7c4ef8f723c3);
#
#
#
#         marker_aaf2002705dd59e148c70d046f2d7c2d.bindPopup(popup_dc4438f824d40bc1a7947b158e2e2927)
#         ;
#
#
#
#
#             var marker_51a8135ea8864a709f005e9ba63bb381 = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_dd75be207fdc3ee7a30144f20d4ab1c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_51a8135ea8864a709f005e9ba63bb381.setIcon(icon_dd75be207fdc3ee7a30144f20d4ab1c7);
#
#
#         var popup_d1a61810d179229362a75449e955d776 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e5c3b766e5fa0a478aa24e0988f0716 = $(`&lt;div id=&quot;html_9e5c3b766e5fa0a478aa24e0988f0716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bengaluru&lt;/div&gt;`)[0];
#                 popup_d1a61810d179229362a75449e955d776.setContent(html_9e5c3b766e5fa0a478aa24e0988f0716);
#
#
#
#         marker_51a8135ea8864a709f005e9ba63bb381.bindPopup(popup_d1a61810d179229362a75449e955d776)
#         ;
#
#
#
#
#             var marker_3cfbd59caf98b5f7b4680e74b873feee = L.marker(
#                 [17.385, 78.4867],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_223593599463064df721d419beda954e = L.AwesomeMa

# %%
# Define the problem
prob = pulp.LpProblem("Facility Location", pulp.LpMinimize)

# Parameters
num_faci = 50
num_dema = 50
# Out:
# /home/delhivery/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1316: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
x = pulp.LpVariable.dicts('X', range(num_faci), cat='Binary')
y = pulp.LpVariable.dicts('Y', (range(num_dema), range(num_faci)), cat='Binary')

# %%
# Objective function
prob += pulp.lpSum(y[demand][facility] * data.iloc[facility, demand]
                   for demand in range(num_dema)
                   for facility in range(num_faci))

# %%
#Total number of facilities constraint = 3
prob += pulp.lpSum(x[facility] for facility in range(num_faci)) == 10, 'Total_Facilities'

# Every demand zone is connected to one facility only
for demand in range(num_dema):
    prob += pulp.lpSum(y[demand][facility] for facility in range(num_faci)) == 1, f'demand_{demand}'

# Contingency Condition: yij <= xi
for demand in range(num_dema):
    for facility in range(num_faci):
        prob += y[demand][facility] <= x[facility], f'Contingency_{demand}_{facility}'

# %%
# Solve the problem
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/delhivery/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8daf08bfe9a64bbc97505f6ad0a3c834-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/8daf08bfe9a64bbc97505f6ad0a3c834-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2556 COLUMNS
# At line 17657 RHS
# At line 20209 BOUNDS
# At line 22760 ENDATA
# Problem MODEL has 2551 rows, 2550 columns and 7550 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7938.63 - 0.05 seconds
# Cgl0004I processed model has 2551 rows, 2550 columns (2550 integer (2550 of which binary)) and 7550 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 7938.63
# Cbc0038I Before mini branch and bound, 2550 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 7938.63 - took 0.00 seconds
# Cbc0012I Integer solution of 7938.6281 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0001I Search completed - best objective 7938.628099929549, took 0 iterations and 0 nodes (0.10 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7938.63 to 7938.63
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7938.62809993
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.12
# 1

# %%
# Print the status
print("Status:", pulp.LpStatus[prob.status])

# Print the results
for facility in range(num_faci):
    if pulp.value(x[facility])== 1:
        print(f'Facility {data.index[facility]} is open')
        #print(f'X[{facility}] =', pulp.value(x[facility]))
    
for demand in range(num_dema):
    for facility in range(num_faci):
        if pulp.value(y[demand][facility])==1:
            print(f'{data.index[facility]} is supplying to {data.index[demand]}')
            #print(f'Y[{demand}][{facility}] =', pulp.value(y[demand][facility]))
# Out:
# Status: Optimal
# Facility Ahmedabad is open
# Facility Pune is open
# Facility Faridabad is open
# Facility Dhanbad is open
# Facility Allahabad is open
# Facility Coimbatore is open
# Facility Jabalpur is open
# Facility Vijayawada is open
# Facility Guwahati is open
# Facility Jalandhar is open
# Pune is supplying to Mumbai
# Faridabad is supplying to Delhi
# Coimbatore is supplying to Bengaluru
# Vijayawada is supplying to Hyderabad
# Ahmedabad is supplying to Ahmedabad
# Vijayawada is supplying to Chennai
# Dhanbad is supplying to Kolkata
# Pune is supplying to Pune
# Faridabad is supplying to Jaipur
# Ahmedabad is supplying to Surat
# Allahabad is supplying to Lucknow
# Allahabad is supplying to Kanpur
# Jabalpur is supplying to Nagpur
# Vijayawada is supplying to Visakhapatnam
# Jabalpur is supplying to Bhopal
# Dhanbad is supplying to Patna
# Jalandhar is supplying to Ludhiana
# Faridabad is supplying to Agra
# Pune is supplying to Nashik
# Faridabad is supplying to Faridabad
# Faridabad is supplying to Meerut
# Ahmedabad is supplying to Rajkot
# Allahabad is supplying to Varanasi
# Jalandhar is supplying to Srinagar
# Pune is supplying to Aurangabad
# Dhanbad is supplying to Dhanbad
# Jalandhar is supplying to Amritsar
# Pune is supplying to Navi Mumbai
# Allahabad is supplying to Allahabad
# Dhanbad is supplying to Ranchi
# Dhanbad is supplying to Howrah
# Coimbatore is supplying to Coimbatore
# Jabalpur is supplying to Jabalpur
# Faridabad is supplying to Gwalior
# Vijayawada is supplying to Vijayawada
# Ahmedabad is supplying to Jodhpur
# Coimbatore is supplying to Madurai
# Jabalpur is supplying to Raipur
# Faridabad is supplying to Kota
# Guwahati is supplying to Guwahati
# Jalandhar is supplying to Chandigarh
# Pune is supplying to Solapur
# Pune is supplying to Hubli
# Coimbatore is supplying to Mysore
# Coimbatore is supplying to Tiruchirappalli
# Faridabad is supplying to Bareilly
# Faridabad is supplying to Aligarh
# Faridabad is supplying to Moradabad
# Faridabad is supplying to Gurgaon
# Jalandhar is supplying to Jalandhar

# %%
# Plot the route
for demand in range(num_dema):
    for facility in range(num_faci):
        if pulp.value(y[demand][facility])==1:
            waypoints = [(data.iloc[facility][50],data.iloc[facility][51]),
                         (data.iloc[demand][50],data.iloc[demand][51])]
            #print(f'{data.index[facility]} is supplying to {data.index[demand]}')
            folium.PolyLine(locations=waypoints, color='blue', weight=2, opacity=1).add_to(map)
# Out:
# /tmp/ipykernel_44729/1238802938.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   waypoints = [(data.iloc[facility][50],data.iloc[facility][51]),
# /tmp/ipykernel_44729/1238802938.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   (data.iloc[demand][50],data.iloc[demand][51])]

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b999ffce51a2739a00877fe1f1803f70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b999ffce51a2739a00877fe1f1803f70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b999ffce51a2739a00877fe1f1803f70 = L.map(
#                 &quot;map_b999ffce51a2739a00877fe1f1803f70&quot;,
#                 {
#                     center: [23.25, 77.41],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e476bd3161744970a87f2dc4577bb5a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 10, &quot;minZoom&quot;: 5, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e476bd3161744970a87f2dc4577bb5a4.addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var marker_3cb9294b1fe728ec82de7e255160a640 = L.marker(
#                 [19.076, 72.8777],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_ac82a2e30d32961a913d0e94fd5acdae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_3cb9294b1fe728ec82de7e255160a640.setIcon(icon_ac82a2e30d32961a913d0e94fd5acdae);
#
#
#         var popup_cc08bad7574c10e7d7b21051014d2983 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d6e678e1cdcfddb73cd573a50604b9e = $(`&lt;div id=&quot;html_4d6e678e1cdcfddb73cd573a50604b9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mumbai&lt;/div&gt;`)[0];
#                 popup_cc08bad7574c10e7d7b21051014d2983.setContent(html_4d6e678e1cdcfddb73cd573a50604b9e);
#
#
#
#         marker_3cb9294b1fe728ec82de7e255160a640.bindPopup(popup_cc08bad7574c10e7d7b21051014d2983)
#         ;
#
#
#
#
#             var marker_aaf2002705dd59e148c70d046f2d7c2d = L.marker(
#                 [28.7041, 77.1025],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_a439165bb65cddcea7f6e7c12477e7c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_aaf2002705dd59e148c70d046f2d7c2d.setIcon(icon_a439165bb65cddcea7f6e7c12477e7c7);
#
#
#         var popup_dc4438f824d40bc1a7947b158e2e2927 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ac81d5b2e67fd92358b7c4ef8f723c3 = $(`&lt;div id=&quot;html_2ac81d5b2e67fd92358b7c4ef8f723c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi&lt;/div&gt;`)[0];
#                 popup_dc4438f824d40bc1a7947b158e2e2927.setContent(html_2ac81d5b2e67fd92358b7c4ef8f723c3);
#
#
#
#         marker_aaf2002705dd59e148c70d046f2d7c2d.bindPopup(popup_dc4438f824d40bc1a7947b158e2e2927)
#         ;
#
#
#
#
#             var marker_51a8135ea8864a709f005e9ba63bb381 = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_dd75be207fdc3ee7a30144f20d4ab1c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;iconSize&quot;: [5, 5], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;shadowSize&quot;: [0, 0]}
#             );
#             marker_51a8135ea8864a709f005e9ba63bb381.setIcon(icon_dd75be207fdc3ee7a30144f20d4ab1c7);
#
#
#         var popup_d1a61810d179229362a75449e955d776 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e5c3b766e5fa0a478aa24e0988f0716 = $(`&lt;div id=&quot;html_9e5c3b766e5fa0a478aa24e0988f0716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bengaluru&lt;/div&gt;`)[0];
#                 popup_d1a61810d179229362a75449e955d776.setContent(html_9e5c3b766e5fa0a478aa24e0988f0716);
#
#
#
#         marker_51a8135ea8864a709f005e9ba63bb381.bindPopup(popup_d1a61810d179229362a75449e955d776)
#         ;
#
#
#
#
#             var marker_3cfbd59caf98b5f7b4680e74b873feee = L.marker(
#                 [17.385, 78.4867],
#                 {}
#             ).addTo(map_b999ffce51a2739a00877fe1f1803f70);
#
#
#             var icon_223593599463064df721d419beda954e = L.AwesomeMa
